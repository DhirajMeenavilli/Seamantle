# %%
import gensim
import math
import pandas as pd
import gensim.downloader as api
import numpy as np
from gensim.models.keyedvectors import KeyedVectors
from english_words import english_words_lower_set as words
# except:
#     import pip 
#     pip.main(['install','pyspellchecker'])

# %%
# wv = api.load('word2vec-google-news-300')
wv = KeyedVectors.load_word2vec_format('betterDict.txt', binary=False)

# %%
# df = pd.DataFrame
words = []
vectors = []
i = 0
for index,word in enumerate(wv.index_to_key):
    a_word = True
    if len(word) > 3 and word[0] == word[1] == word[2]:
        a_word = False
        
    if word.isalpha() and word.lower() == word and len(word) > 3 and word.lower() != word.upper() and a_word:
        words.append(word)
        vectors.append(wv.vectors[wv.get_index(word)])

df = pd.DataFrame(np.array(vectors),index=words)
# Out:
#                  0         1         2         3         4         5    \
# that       -0.015747 -0.028320  0.083496  0.050293 -0.110352  0.031738
# with       -0.024902  0.021973 -0.035400  0.136719  0.016357 -0.027954
# said       -0.009094 -0.044189  0.099609 -0.076172 -0.056641  0.061523
# from        0.058105 -0.000175  0.076172  0.053223  0.025146  0.020874
# have       -0.139648 -0.034668 -0.053711  0.179688 -0.036865 -0.025757
# ...              ...       ...       ...       ...       ...       ...
# llefarydd  -0.024658  0.013855  0.009644 -0.057373  0.065918 -0.006165
# muscaria    0.011475 -0.020386 -0.027344  0.041992 -0.068848  0.013428
# thermopane -0.056885  0.052979  0.026001  0.018188  0.058350 -0.040527
# nuing      -0.037109  0.016479 -0.031494  0.023560 -0.061035  0.000364
# tricorne    0.033691 -0.084961 -0.067383  0.108887 -0.055664 -0.010132
#
#                  6         7         8         9    ...       290       291  \
# that       -0.014221 -0.089844  0.117676  0.118164  ... -0.011292 -0.015625
# with       -0.024292 -0.139648  0.057373  0.062256  ... -0.020752  0.003082
# said        0.255859 -0.158203  0.016602 -0.096680  ... -0.193359  0.029907
# from       -0.069336 -0.132812 -0.069336  0.164062  ... -0.296875  0.058594
# have        0.004852 -0.083496  0.008179  0.324219  ... -0.049072  0.063477
# ...              ...       ...       ...       ...  ...       ...       ...
# llefarydd   0.028931 -0.035400  0.003799  0.038574  ...  0.001740  0.007385
# muscaria   -0.028198  0.014160 -0.063965 -0.026733  ...  0.041016  0.039551
# thermopane  0.095703 -0.048340  0.093750  0.089844  ... -0.063965  0.038330
# nuing       0.006714  0.063477 -0.110352  0.038574  ... -0.041992  0.062988
# tricorne   -0.010559  0.001793 -0.041748  0.018799  ... -0.029175 -0.048828
#
#                  292       293       294       295       296       297  \
# that       -0.033447 -0.020630 -0.019409  0.063965  0.020142  0.006866
# with       -0.138672 -0.024414 -0.093262 -0.047607 -0.075684  0.010803
# said       -0.093262  0.053711 -0.117676  0.069824  0.105957  0.144531
# from        0.001579  0.015625 -0.009766  0.136719  0.111328  0.010132
# have        0.080566  0.088867  0.077637 -0.046631 -0.071777 -0.118164
# ...              ...       ...       ...       ...       ...       ...
# llefarydd  -0.026611  0.056152 -0.073730 -0.062256  0.033203  0.005981
# muscaria    0.035156  0.024658 -0.014648 -0.025024 -0.009277 -0.008240
# thermopane -0.001450  0.083496  0.033447 -0.041504 -0.027344 -0.003738
# nuing      -0.053467  0.073730  0.018677  0.015564  0.054199  0.004150
# tricorne   -0.057617  0.018555  0.074219 -0.045898  0.048096  0.021851
#
#                  298       299
# that        0.061035 -0.148438
# with       -0.018799 -0.068848
# said        0.180664 -0.086914
# from        0.064453 -0.029663
# have       -0.002457 -0.072266
# ...              ...       ...
# llefarydd   0.028320  0.054199
# muscaria    0.101562  0.095703
# thermopane  0.073242  0.018677
# nuing      -0.012146 -0.007385
# tricorne   -0.011353  0.071289
#
# [151406 rows x 300 columns]

# %%
np.savetxt('betterDict.txt', df.reset_index().values, 
           delimiter=" ", 
           header="{} {}".format(len(df), len(df.columns)),
           comments="",
           fmt=["%s"] + ["%.18e"]*len(df.columns))

# %%
#------------------------------------------ INTELLIGENT BRUTE FORCE ----------------------------------------------#

# %%
i = 0
fil = open('test.txt','w')
for index,word in enumerate(wv.index_to_key):
    closest = wv.most_similar(word,topn=1)
    fil.write(word + ' ' + closest[0][0] + ' ' + str(closest[0][1]) + '\n')
fil.close()
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000

# %%
data = pd.read_csv('test.txt',sep = " ", header = None)
data.columns = ['word','closest','simmilarity']

# %%
print(data.loc[data['word'] == 'precious'])
wv.most_similar('limited',topn=1)
# Out:
#           word    closest  simmilarity
# 5925  precious  priceless     0.637004
# [('restricted', 0.585472047328949)]

# %%
df = data.loc[data['simmilarity'] > 0.58545]
df = df.loc[data['simmilarity'] <= 0.58555]
df.sort_values(by=['simmilarity'])
# Out:
#                  word          closest  simmilarity
# 56035        uploader          uploads     0.585456
# 49498    chauffeuring       chauffered     0.585457
# 47013        clamming             clam     0.585471
# 870           limited       restricted     0.585472
# 40514   neuromuscular         postural     0.585472
# 109113       woodyard         debarker     0.585474
# 96731           laffs             yuks     0.585478
# 148290        vasquez             diaz     0.585483
# 110730    spiderlings         froglets     0.585486
# 128730     pantagraph           kotaku     0.585486
# 77030        drillbit           uphole     0.585491
# 127247        batlike          gorgons     0.585493
# 54123          heeler       bulldogger     0.585494
# 115603          tendu          lauhala     0.585495
# 69673         sambuca           kahlua     0.585495
# 114495      cruelness  remorselessness     0.585497
# 33412            cams          cameras     0.585497
# 58063       botulinum          botulin     0.585499
# 74786        maltreat       dehumanise     0.585500
# 50838       roundness         waviness     0.585500
# 137794     planetside        dropships     0.585505
# 75669         gurgler         plughole     0.585508
# 64913        plughole          gurgler     0.585508
# 120907    demotivates      disempowers     0.585509
# 92069          arguer       ineloquent     0.585513
# 89059      osmolarity      lacrimation     0.585514
# 105137    crayfishing         prawning     0.585514
# 132488      bikeshare        metrorail     0.585516
# 107147   philosphical    philosophical     0.585517
# 135095       wheezers    osteosarcomas     0.585525
# 112378      milimetre        milimeter     0.585531
# 113554   speedbreaker    speedbreakers     0.585533
# 63184       incurably       terminally     0.585536
# 70065         decamps           decamp     0.585538
# 144395     feasiblity      feasibility     0.585541
# 18463     recoverable    unrecoverable     0.585542
# 149320     directeurs         sportifs     0.585543
# 78294       harrumphs           sneers     0.585544
# 98899       sitaution        situation     0.585547
# 47343         rutting           mating     0.585547
# 56692       fixturing         fixtured     0.585549
# 84552        fixtured        fixturing     0.585549

# %%
#---------------------------------------------- RL: DQN ----------------------------------------------------------#

# %%
alpha = 0.1
gamma = 0.9
